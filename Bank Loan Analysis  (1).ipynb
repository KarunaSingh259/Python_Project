# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px

# %%
df = pd.read_excel('financial_loan.xlsx')
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %% [markdown]
# # **Metadata of data**

# %%
print("No of Rows -", df.shape[0])
print("No of Columns -", df.shape[1])
# Out:
# No of Rows - 38576
# No of Columns - 24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %% [markdown]
# # **Data types**

# %%
df.dtypes
# Out:
# id                                int64
# address_state                    object
# application_type                 object
# emp_length                       object
# emp_title                        object
# grade                            object
# home_ownership                   object
# issue_date               datetime64[ns]
# last_credit_pull_date    datetime64[ns]
# last_payment_date        datetime64[ns]
# loan_status                      object
# next_payment_date        datetime64[ns]
# member_id                         int64
# purpose                          object
# sub_grade                        object
# term                             object
# verification_status              object
# annual_income                   float64
# dti                             float64
# installment                     float64
# int_rate                        float64
# loan_amount                       int64
# total_acc                         int64
# ...

# %%
df.describe()
# Out:
#                  id                     issue_date  \
# count  3.857600e+04                          38576
# mean   6.810371e+05  2021-07-16 02:31:35.562007040
# min    5.473400e+04            2021-01-01 00:00:00
# 25%    5.135170e+05            2021-04-11 00:00:00
# 50%    6.627280e+05            2021-07-11 00:00:00
# 75%    8.365060e+05            2021-10-11 00:00:00
# max    1.077501e+06            2021-12-12 00:00:00
# std    2.113246e+05                            NaN
#
#                last_credit_pull_date              last_payment_date  \
# count                          38576                          38576
# mean   2021-06-08 13:36:34.193280512  2021-06-26 09:52:08.909166080
# min              2021-01-08 00:00:00            2021-01-08 00:00:00
# 25%              2021-04-15 00:00:00            2021-03-16 00:00:00
# 50%              2021-05-16 00:00:00            2021-06-14 00:00:00
# 75%              2021-08-13 00:00:00            2021-09-15 00:00:00
# ...

# %% [markdown]
# # Total Loan Application

# %%
total_loan_application = df['id'].count()
print("Total Loan Application-", total_loan_application)
# Out:
# Total Loan Application- 38576

# %% [markdown]
# # **Month To Date Total Application**

# %%
latest_issue_date = df['issue_date'].max()
latest_year = latest_issue_date.year
latest_month = latest_issue_date.month

mtd_date = df[(df['issue_date'].dt.year == latest_year) & (df['issue_date'].dt.month == latest_month)]
mtd_total_application = mtd_date['id'].count()
print(f"Month To Date Total Application(for{latest_issue_date.strftime('%B %Y')})- , { mtd_total_application}")
# Out:
# Month To Date Total Application(forDecember 2021)- , 4314

# %% [markdown]
# # Total Funded Amount

# %%
total_Funded_amount = df['loan_amount'].sum()
print("Total Funded Amount -", total_Funded_amount)
# Out:
# Total Funded Amount - 435757075

# %% [markdown]
# # Month To Date Funded Amount

# %%
latest_issue_date = df['issue_date'].max()
latest_year = latest_issue_date.year
latest_month = latest_issue_date.month

mtd_date = df[(df['issue_date'].dt.year == latest_year) & (df['issue_date'].dt.month == latest_month)]
mtd_total_funded_amount = mtd_date['loan_amount'].sum()
print(f"Month To Date Funded Amount(for{latest_issue_date.strftime('%B %Y')})- { mtd_total_funded_amount}")
# Out:
# Month To Date Funded Amount(forDecember 2021)- 53981425

# %% [markdown]
# # Total Amount Received

# %%
total_amount_received = df['total_payment'].sum()
print("Total Amount Received -", total_amount_received)
# Out:
# Total Amount Received - 473070933

# %% [markdown]
# # Month To Date Total Amount Received

# %%
latest_issue_date = df['issue_date'].max()
latest_year = latest_issue_date.year
latest_month = latest_issue_date.month

mtd_date = df[(df['issue_date'].dt.year == latest_year) & (df['issue_date'].dt.month == latest_month)]
mtd_total_amount_received = mtd_date['total_payment'].sum()
print(f"Month To Date Amount Received (for{latest_issue_date.strftime('%B %Y')})- { mtd_total_amount_received}")
# Out:
# Month To Date Amount Received (forDecember 2021)- 58074380

# %% [markdown]
# # Average Interest Rate

# %%
average_interest_rate = df['int_rate'].mean()*100
print("Average Interest Rate - {:.2f}% ".format( average_interest_rate))
# Out:
# Average Interest Rate - 12.05%

# %% [markdown]
# # Average Debt-to-Income Ratio(DTI)

# %%
average_dti = df['dti'].mean()*100
print("Average Debt-to-Income Ratio - {:.2f}% ".format( average_dti))
# Out:
# Average Debt-to-Income Ratio - 13.33%

# %% [markdown]
# # Good Loan Matrics

# %%
good_loans = df [df['loan_status'].isin(["Fully Paid", "Current"])]
total_loan_applications = df['id'].count()
good_loan_applications = good_loans ['id'].count()
good_loan_funded_amount= good_loans ['loan_amount'].sum()
good_loan_received = good_loans ['total_payment'].sum()
good_loan_funded_amount_millions = good_loan_funded_amount / 1000000
good_loan_received_millions=good_loan_received / 1000000
good_loan_percentage = (good_loan_applications / total_loan_applications)* 100
print("Good Loan Applications: ", good_loan_applications)
print("Good Loan Funded Amount (in Millions): ${:.2f}M".format(good_loan_funded_amount_millions))
print("Good Loan Total Received (in Millions): ${:.2f}M". format (good_loan_received_millions))
print("Percentage of Good Loan Applications: {:.2f}%".format(good_loan_percentage))
# Out:
# Good Loan Applications:  33243
# Good Loan Funded Amount (in Millions): $370.22M
# Good Loan Total Received (in Millions): $435.79M
# Percentage of Good Loan Applications: 86.18%

# %% [markdown]
# # Bad Loan Matrics

# %%
bad_loans = df [df['loan_status'].isin(["Charged Off"])]
total_loan_applications = df['id'].count()
bad_loan_applications = bad_loans ['id'].count()
bad_loan_funded_amount= bad_loans ['loan_amount'].sum()
bad_loan_received = bad_loans ['total_payment'].sum()
bad_loan_funded_amount_millions = bad_loan_funded_amount / 1000000
bad_loan_received_millions=bad_loan_received / 1000000
bad_loan_percentage = (bad_loan_applications / total_loan_applications)* 100
print("Bad Loan Applications: ", bad_loan_applications)
print("Bad Loan Funded Amount (in Millions): ${:.2f}M".format(bad_loan_funded_amount_millions))
print("Bad Loan Total Received (in Millions): ${:.2f}M".format(bad_loan_received_millions))
print("Percentage of Bad Loan Applications: {:.2f}%".format(bad_loan_percentage))
# Out:
# Bad Loan Applications:  5333
# Bad Loan Funded Amount (in Millions): $65.53M
# Bad Loan Total Received (in Millions): $37.28M
# Percentage of Bad Loan Applications: 13.82%

# %% [markdown]
# # Total Funded Amount

# %% [markdown]
# ## Monthly Treads by Issue Date For Total Funded Amount

# %%
monthly_funded = (
    df.sort_values('issue_date')
    .assign(month_name=lambda x: x['issue_date'].dt.strftime('%b %Y'))
    .groupby('month_name', sort=False) ['loan_amount']
    .sum()
    .div(1000000)
    .reset_index(name='loan_amount_millions')
)


plt.figure(figsize=(10, 5))
plt.fill_between (monthly_funded ['month_name'], monthly_funded [ 'loan_amount_millions'], color='skyblue', alpha=0.5)
plt.plot(monthly_funded [ 'month_name'], monthly_funded [ 'loan_amount_millions'], color='blue', linewidth=2)


for i, row in monthly_funded.iterrows():
  plt.text(i, row['loan_amount_millions'] +0.1, f" {row['loan_amount_millions']:.2f}",
           ha='center', va='bottom', fontsize=9, rotation=0, color='black')
plt.title('Total Funded Amount by Month', fontsize=14)
plt.xlabel('Month')
plt.ylabel('Funded Amount ( Millions)')
plt.xticks(ticks=range(len(monthly_funded)), labels=monthly_funded [ 'month_name'], rotation=45)
plt.grid(True, linestyle= '--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Total Received Amount by Month

# %%
monthly_received = (
    df.sort_values('issue_date')
    .assign(month_name=lambda x: x['issue_date'].dt.strftime('%b %Y'))
    .groupby('month_name', sort=False) ['total_payment']
    .sum()
    .div(1000000)
    .reset_index(name='received_amount_millions')
)


plt.figure(figsize=(10, 5))
plt.fill_between (monthly_received ['month_name'], monthly_received [ 'received_amount_millions'], color='lightgreen', alpha=0.5)
plt.plot(monthly_received [ 'month_name'], monthly_received [ 'received_amount_millions'], color='green', linewidth=2)


for i, row in monthly_received.iterrows():
  plt.text(i, row['received_amount_millions'] +0.1, f" {row['received_amount_millions']:.2f}",
           ha='center', va='bottom', fontsize=9, rotation=0, color='black')
plt.title('Total Received Amount by Month', fontsize=14)
plt.xlabel('Month')
plt.ylabel('Received Amount ( Millions)')
plt.xticks(ticks=range(len(monthly_received)), labels=monthly_received [ 'month_name'], rotation=45)
plt.grid(True, linestyle= '--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly Treads by Issue Date For Total Loan Application

# %%
import matplotlib.pyplot as plt

monthly_applications = (
    df.sort_values('issue_date')
      .assign(month_name=lambda x: x['issue_date'].dt.strftime('%b %Y'))
      .groupby('month_name', sort=False)['id']
      .count()
      .reset_index(name='loan_applications_count')
)

plt.figure(figsize=(10, 5))


plt.fill_between(
    monthly_applications['month_name'],
    monthly_applications['loan_applications_count'],
    color='orange', alpha=0.5
)


plt.plot(
    monthly_applications['month_name'],
    monthly_applications['loan_applications_count'],
    color='black', linewidth=2
)

for i, row in monthly_applications.iterrows():
    plt.text(i, row['loan_applications_count'] + 0.5,
             f"{row['loan_applications_count']}",
             ha='center', va='bottom', fontsize=9, color='black')

plt.title('Total Loan Applications by Month', fontsize=14)
plt.xlabel('Month')
plt.ylabel('Number of Applications')
plt.xticks(
    ticks=range(len(monthly_applications)),
    labels=monthly_applications['month_name'],
    rotation=45
)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Regional Analysis by State for Total Funded Amount

# %%
state_funding = (
    df.groupby('address_state')['loan_amount']
      .sum()
      .sort_values(ascending=True)
)

state_funding_thousands = state_funding / 1000


plt.figure(figsize=(12, 10))
bars = plt.barh(
    state_funding_thousands.index,
    state_funding_thousands.values,
    color='lightcoral'
)

for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 10,
        bar.get_y() + bar.get_height() / 2,
        f'{width:,.0f}K',
        va='center',
        fontsize=9
    )

plt.title('Total Funded Amount by State (in Thousands)')
plt.xlabel("Funded Amount (* '000)")
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Loan Term Analysis by Total Funded Amount

# %%
term_funding_millions = df.groupby('term')['loan_amount'].sum() / 1_000_000

plt.figure(figsize=(5, 5))



plt.pie(
    term_funding_millions,
    labels=term_funding_millions.index,
    autopct=lambda p: f"{p:.1f}%\n${p*sum(term_funding_millions)/100:.1f}M",
    startangle=90,
    wedgeprops={'width': 0.4}
)


centre_circle = plt.Circle((0, 0), 0.70, color='white')
plt.gca().add_artist(centre_circle)

plt.title("Total Funded Amount by Term (in $ Millions)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Employee Length by Total Funded Amount

# %%
emp_funding = df.groupby('emp_length')['loan_amount'].sum().sort_values() / 1000

plt.figure(figsize=(15, 6))
bars = plt.barh(emp_funding.index, emp_funding.values, color='purple')

for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 5,
        bar.get_y() + bar.get_height() / 2,
        f"{width:,.0f}K",
        va='center',
        fontsize=9
    )

plt.xlabel("Funded Amount (Thousands)")
plt.title("Total Funded Amount by Employment Length")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Loan Purpose by Total Funded Amount

# %%
purpose_funding_millions = (
    df.groupby('purpose')['loan_amount']
      .sum()
      .sort_values() / 1_000_000
)

plt.figure(figsize=(10, 6))
bars = plt.barh(
    purpose_funding_millions.index,
    purpose_funding_millions.values,
    color='skyblue'
)

for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 0.1,
        bar.get_y() + bar.get_height() / 2,
        f'{width:.2f}M',
        va='center',
        fontsize=9
    )

plt.title('Total Funded Amount by Loan Purpose (in Millions)', fontsize=14)
plt.xlabel('Funded Amount (Millions)')
plt.ylabel('Loan Purpose')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Home ownership by Total Funded Amount

# %%
home_funding = df.groupby('home_ownership')['loan_amount'].sum().reset_index()
home_funding['loan_amount_millions'] = home_funding['loan_amount'] / 1_000_000

fig = px.treemap(
    home_funding,
    path=['home_ownership'],
    values='loan_amount_millions',
    color='loan_amount_millions',
    color_continuous_scale='Blues',
    title='Total Funded Amount by Home Ownership (in Millions)'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Total Loan Applications**

# %% [markdown]
# # Monthly Treads by Issue Date For Total Amount Received

# %%
monthly = df.groupby("month").agg(applications=(amount_col,"count")).reset_index()

plt.figure(figsize=(10,5))
plt.plot(monthly["month"], monthly["applications"], marker="o")
plt.fill_between(monthly["month"], monthly["applications"], alpha=0.2)
plt.title("Monthly Trends - Applications")
plt.xlabel("Month")
plt.ylabel("Applications")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Regional Analysis – Applications

# %%
state_group = df.groupby(state_col).agg(applications=(amount_col,"count")).sort_values("applications", ascending=False)

state_group.plot(kind="bar", figsize=(10,5), color="skyblue", edgecolor="black")
plt.title("Regional Analysis - Applications")
plt.xlabel("State")
plt.ylabel("Applications")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Loan Term – Applications (Donut)

# %%
term_group = df.groupby(term_col).agg(applications=(amount_col,"count")).reset_index()

plt.pie(term_group["applications"], labels=term_group[term_col], autopct="%1.1f%%",
        startangle=90, wedgeprops={'width':0.4})
plt.title("Loan Term Analysis - Applications")
plt.show()

# %% [markdown]
# # Employee Length – Applications

# %%
emp_group = df.groupby(emp_col).agg(applications=(amount_col,"count")).sort_values("applications", ascending=False)

emp_group.plot(kind="bar", figsize=(10,5), color="skyblue", edgecolor="black")
plt.title("Employee Length - Applications")
plt.xlabel("Employee Length")
plt.ylabel("Applications")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Loan Purpose – Applications

# %%
purpose_group = df.groupby(purpose_col).agg(applications=(amount_col,"count")).sort_values("applications", ascending=False)

purpose_group.plot(kind="bar", figsize=(10,5), color="skyblue", edgecolor="black")
plt.title("Loan Purpose - Applications")
plt.xlabel("Purpose")
plt.ylabel("Applications")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Home Ownership – Applications (Treemap)

# %%
home_group = df.groupby(home_col).agg(applications=(amount_col,"count")).reset_index()

fig = px.treemap(home_group, path=[home_col], values="applications", title="Home Ownership - Applications")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Amount Received**

# %% [markdown]
# ## Monthly Trends – Amount Received

# %%
monthly = df.groupby("month").agg(amount_received=(amount_col,"sum")).reset_index()

plt.figure(figsize=(10,5))
plt.plot(monthly["month"], monthly["amount_received"], marker="o", color="orange")
plt.fill_between(monthly["month"], monthly["amount_received"], alpha=0.2, color="orange")
plt.title("Monthly Trends - Amount Received")
plt.xlabel("Month")
plt.ylabel("Amount")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Regional Analysis – Amount Received

# %%
state_group = df.groupby(state_col).agg(amount_received=(amount_col,"sum")).sort_values("amount_received", ascending=False)

state_group.plot(kind="bar", figsize=(10,5), color="orange", edgecolor="black")
plt.title("Regional Analysis - Amount Received")
plt.xlabel("State")
plt.ylabel("Amount")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Loan Term – Amount Received (Donut)

# %%
term_group = df.groupby(term_col).agg(amount_received=(amount_col,"sum")).reset_index()

plt.pie(term_group["amount_received"], labels=term_group[term_col], autopct="%1.1f%%",
        startangle=90, wedgeprops={'width':0.4}, colors=["orange","gold","lightcoral","skyblue"])
plt.title("Loan Term Analysis - Amount Received")
plt.show()

# %% [markdown]
# ## Employee Length – Amount Received

# %%
emp_group = df.groupby(emp_col).agg(amount_received=(amount_col,"sum")).sort_values("amount_received", ascending=False)

emp_group.plot(kind="bar", figsize=(10,5), color="orange", edgecolor="black")
plt.title("Employee Length - Amount Received")
plt.xlabel("Employee Length")
plt.ylabel("Amount")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Loan Purpose – Amount Received

# %%
purpose_group = df.groupby(purpose_col).agg(amount_received=(amount_col,"sum")).sort_values("amount_received", ascending=False)

purpose_group.plot(kind="bar", figsize=(10,5), color="orange", edgecolor="black")
plt.title("Loan Purpose - Amount Received")
plt.xlabel("Purpose")
plt.ylabel("Amount")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Home Ownership – Amount Received (Treemap)

# %%
home_group = df.groupby(home_col).agg(amount_received=(amount_col,"sum")).reset_index()

fig = px.treemap(home_group, path=[home_col], values="amount_received", title="Home Ownership - Amount Received")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
